# %%
import struct
import numpy
from pointer import Pointer

# %%
#Put all bytes from target file into memmap array
target_file = numpy.memmap(filename = "tests/samples/dummy.root", mode = "r", dtype = numpy.uint8, shape = (928,))

# %%
_format1       = ">4si"
_format2_small = ">iiiiiiBiii18s"
_format2_big   = ">iqqiiiBiqi18s"
_format3       = ">hIIii"
_format4_small = ">iii"
_format4_big   = ">qqq"
_format5       = ">i"
_format_small  = ">ihiIhhii"
_format_big    = ">ihiIhhqq"
_startcheck_format = ">IH"

# %%
name = input("Enter name of the ROOT file - ")
if name.endswith(".root") is False:
    name = name + ".root"
file = numpy.memmap(filename = name, dtype = numpy.uint8, mode = "w+", shape = (928,))
#In the case of a 1D array, the shape is the size of the file
#In ROOT files, the fEND corresponds to the size of the file
#fEND for ~/Downloads/uproot/tests/samples/dummy.root is 928

# %%
#Working on just replacing bytes on target_file
file = numpy.memmap(filename = "uprootTObjString.root", dtype = numpy.uint8, mode = "w+", shape = (928,))
file[:] = target_file[:]

# %%
#Header bytes
fVersion = 61400 #Constant
magic = b"root"
count = Pointer(0)
toadd = count.push(_format1, magic, fVersion)
file[count.origin:count.index] = toadd
#constants for file dummy.root
count.origin = count.index
fBEGIN = 100 #Constant
fEND = 928 
fSeekFree = 874
fNbytesFree = fEND - fSeekFree
nfree = 1
fNbytesName = 56
fUnits = 4
fCompress = 0
fSeekInfo = 318
fNbytesInfo = 434
fUUID = b"\x00\x010\xd5\xf5\xea~\x0b\x11\xe8\xa2D~S\x1f\xac\xbe\xef"
toadd = count.push(_format2_small, fBEGIN, fEND, fSeekFree, fNbytesFree, nfree, fNbytesName, fUnits, fCompress, fSeekInfo, fNbytesInfo, fUUID)
file[count.origin:count.index] = toadd

# %%
#Streamer Key
newpos = Pointer(fSeekInfo)
fNbytes = fNbytesInfo
fVersion = 4
fObjlen = 370
fDatime = 1573188772
fKeylen = 64
fCycle = 1
fSeekKey = newpos.index
fSeekPdir = 100
toadd = newpos.push(_format_small, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)
file[newpos.origin:newpos.index] = toadd
newpos.origin = newpos.index

fClassName = b'TList'
fName = b'StreamerInfo'
fTitle = b'Doubly linked list'
file[newpos.index] = newpos.precheck(fClassName)
toadd = newpos.string(fClassName)
file[newpos.origin:newpos.index] = toadd
newpos.origin = newpos.index
file[newpos.index] = newpos.precheck(fName)
toadd = newpos.string(fName)
file[newpos.origin:newpos.index] = toadd
newpos.origin = newpos.index
file[newpos] = newpos.precheck(fTitle)
toadd = newpos.string(fTitle)
file[newpos.origin:newpos.index] = toadd
newpos.origin = newpos.index

# %%
#TList Streamer
cnt = 1073742190
vers = 5
toadd = numpy.frombuffer(struct.pack(">IH", cnt, vers), dtype = numpy.uint8)
print (numpy.shape(toadd))
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

version = 1
toadd = numpy.frombuffer(struct.pack(">h", version), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fUniqueID =  0
fBits =  33554432
packer = ">II"
toadd = numpy.frombuffer(struct.pack(packer, fUniqueID, fBits), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

name = b""
file[newpos] = bytes(str(len(name)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(name))] = numpy.frombuffer(name, dtype = numpy.uint8)
newpos = newpos + len(name)
size = 1
toadd = numpy.frombuffer(struct.pack(">i", size), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

bcnt =  1073742168
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, bcnt), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

tag =  4294967295
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, tag), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

cname = b"TStreamerInfo"
file[newpos:(newpos + len(cname))] = numpy.frombuffer(cname, dtype = numpy.uint8)
newpos = newpos + len(cname)

# %%
#TStreamerInfo Streamer
newpos =  newpos + 1
cnt =  1073742146
vers =  9
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

cnt =  1073741848
vers =  1
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

version = 1
packer = ">h"
toadd = numpy.frombuffer(struct.pack(packer, version), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fUniqueID = 0
fBits =  50397184
packer = ">II"
toadd = numpy.frombuffer(struct.pack(packer, fUniqueID, fBits), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

name = b'TObjString'
title = b''
file[newpos] = bytes(str(len(name)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(name))] = numpy.frombuffer(name, dtype = numpy.uint8)
newpos = newpos + len(name)
file[newpos] = bytes(str(len(title)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(title))] = numpy.frombuffer(title, dtype = numpy.uint8)
newpos = newpos + len(title)

fCheckSum =  2626570240
fClassVersion = 1
packer = ">Ii"
toadd = numpy.frombuffer(struct.pack(packer, fCheckSum, fClassVersion), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

bcnt =  1073742104
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, bcnt), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

tag =  4294967295
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, tag), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

cname = b"TObjArray"
file[newpos:(newpos + len(cname))] = numpy.frombuffer(cname, dtype = numpy.uint8)
newpos = newpos + len(cname)

# %%
#TObjArray Streamer
newpos = newpos + 1
cnt =  1073742086
vers =  3
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

version = 1
packer = ">h"
toadd = numpy.frombuffer(struct.pack(packer, version), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fUniqueID =  0
fBits =  33554432
packer = ">II"
toadd = numpy.frombuffer(struct.pack(packer, fUniqueID, fBits), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

name =  b''
file[newpos] = bytes(str(len(name)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(name))] = numpy.frombuffer(name, dtype = numpy.uint8)
newpos = newpos + len(name)
size =  2
low =  0
packer = ">ii"
toadd = numpy.frombuffer(struct.pack(packer, size, low), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

bcnt =  1073741941
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, bcnt), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

tag =  4294967295
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, tag), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

cname =  b"TStreamerBase"
file[newpos:(newpos + len(cname))] = numpy.frombuffer(cname, dtype = numpy.uint8)
newpos = newpos + len(cname)

# %%
#TStreamerBase Streamer
newpos = newpos + 1
cnt =  1073741919
vers =  3
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

# %%
#TStreamerElement Streamer
cnt =  1073741909
vers =  4
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

cnt =  1073741862
vers =  1
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

version = 1
packer = ">h"
toadd = numpy.frombuffer(struct.pack(packer, version), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fUniqueID =  0
fBits =  50331648
packer = ">II"
toadd = numpy.frombuffer(struct.pack(packer, fUniqueID, fBits), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

name = b'TObject'
title = b'Basic ROOT object'
file[newpos] = bytes(str(len(name)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(name))] = numpy.frombuffer(name, dtype = numpy.uint8)
newpos = newpos + len(name)
file[newpos] = bytes(str(len(title)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(title))] = numpy.frombuffer(title, dtype = numpy.uint8)
newpos = newpos + len(title)

fType =  66
fSize =  0
fArrayLength =  0
fArrayDim =  0
packer = ">iiii"
toadd = numpy.frombuffer(struct.pack(packer, fType, fSize, fArrayLength, fArrayDim), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fMaxIndex =  [0, -1877229523, 0, 0, 0]
buffer = bytearray()
packer = ">i"
for x in fMaxIndex:
    buffer = buffer + struct.pack(packer, x)
toadd = numpy.frombuffer(buffer, dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fTypeName =  b'BASE'
file[newpos] = bytes(str(len(fTypeName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fTypeName))] = numpy.frombuffer(fTypeName, dtype = numpy.uint8)
newpos = newpos + len(fTypeName)

fBaseVersion =  1
packer = ">i"
toadd = numpy.frombuffer(struct.pack(packer, fBaseVersion), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

bcnt =  1073741940
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, bcnt), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

tag =  4294967295
packer = ">I"
toadd = numpy.frombuffer(struct.pack(packer, tag), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

cname =  b"TStreamerString"
file[newpos:(newpos + len(cname))] = numpy.frombuffer(cname, dtype = numpy.uint8)
newpos = newpos + len(cname)

# %%
#TStreamerString Streamer
newpos =  newpos + 1
cnt =  1073741916
vers =  2
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

# %%
#TStreamerElement Streamer
cnt =  1073741910
vers =  4
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

cnt =  1073741860
vers =  1
packer = ">IH"
toadd = numpy.frombuffer(struct.pack(packer, cnt, vers), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

version = 1
packer = ">h"
toadd = numpy.frombuffer(struct.pack(packer, version), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fUniqueID =  0
fBits =  50331648
packer = ">II"
toadd = numpy.frombuffer(struct.pack(packer, fUniqueID, fBits), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

name = b'fString'
title = b'wrapped TString'
file[newpos] = bytes(str(len(name)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(name))] = numpy.frombuffer(name, dtype = numpy.uint8)
newpos = newpos + len(name)
file[newpos] = bytes(str(len(title)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(title))] = numpy.frombuffer(title, dtype = numpy.uint8)
newpos = newpos + len(title)

fType =  65
fSize =  24
fArrayLength =  0
fArrayDim =  0
packer = ">iiii"
toadd = numpy.frombuffer(struct.pack(packer, fType, fSize, fArrayLength, fArrayDim), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fMaxIndex =  [0, 0, 0, 0, 0]
buffer = bytearray()
packer = ">i"
for x in fMaxIndex:
    buffer = buffer + struct.pack(packer, x)
toadd = numpy.frombuffer(buffer, dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

fTypeName =  b'TString'
file[newpos] = bytes(str(len(fTypeName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fTypeName))] = numpy.frombuffer(fTypeName, dtype = numpy.uint8)
newpos = newpos + len(fTypeName)

n =  0
packer = ">B"
toadd = numpy.frombuffer(struct.pack(packer, n), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

data =  bytearray()
toadd = numpy.frombuffer(data, dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

# %%
#Tkey instance
start = fBEGIN
fNbytes = 116
fVersion = 4
fObjlen = 72
fDatime = 1573188772
fKeylen = 44
fCycle = 1
fSeekKey = 100
fSeekPdir = 0
toadd = numpy.frombuffer(struct.pack(_format_small, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir), dtype = numpy.uint8)
file[start:(start + len(toadd))] = toadd
newpos = start + len(toadd)
fClassName = b'TFile'
fName = b'dummy.root'
fTitle = b''
file[newpos] = bytes(str(len(fClassName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fClassName))] = numpy.frombuffer(fClassName, dtype = numpy.uint8)
newpos = newpos + len(fClassName)
file[newpos] = bytes(str(len(fName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fName))] = numpy.frombuffer(fName, dtype = numpy.uint8)
newpos = newpos + len(fName)
file[newpos] = bytes(str(len(fTitle)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fTitle))] = numpy.frombuffer(fTitle, dtype = numpy.uint8)

# %%
#Directory Information
newpos = 156
fVersion = 5
fDatimeC = 1573188772
fDatimeM = 1573188772
fNbytesKeys = 122
fNbytesName = fNbytesName
fSeekDir = 100
fSeekParent = 0
fSeekKeys = 752
toadd = numpy.frombuffer(struct.pack(_format3, fVersion, fDatimeC, fDatimeM, fNbytesKeys, fNbytesName), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)
toadd = numpy.frombuffer(struct.pack(_format4_small, fSeekDir, fSeekParent, fSeekKeys), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

# %%
#Header Key
start = fSeekKeys
fNbytes = 122
fVersion = 4
fObjlen = 48
fDatime = 1573188772
fKeylen = 44
fCycle = 1
fSeekKey = 752
fSeekPdir = 100
toadd = numpy.frombuffer(struct.pack(_format_small, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir), dtype = numpy.uint8)
file[start:(start + len(toadd))] = toadd

newpos = start + len(toadd)
fClassName = b'TFile'
fName = b'dummy.root'
fTitle = b''
file[newpos] = bytes(str(len(fClassName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fClassName))] = numpy.frombuffer(fClassName, dtype = numpy.uint8)
newpos = newpos + len(fClassName)
file[newpos] = bytes(str(len(fName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fName))] = numpy.frombuffer(fName, dtype = numpy.uint8)
newpos = newpos + len(fName)
file[newpos] = bytes(str(len(fTitle)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fTitle))] = numpy.frombuffer(fTitle, dtype = numpy.uint8)
newpos = newpos + len(toadd)

# %%
#Read number of keys
nkeys = 1
newpos = 796
toadd = numpy.frombuffer(struct.pack(_format5, nkeys), dtype = numpy.uint8)
file[newpos:(newpos + len(toadd))] = toadd
newpos = newpos + len(toadd)

# %%
#Tkey instance 
start = 800
fNbytes = 102
fVersion = 4
fObjlen = 28
fDatime = 1573188772
fKeylen = 74
fCycle = 1
fSeekKey = 216
fSeekPdir = 100
toadd = numpy.frombuffer(struct.pack(_format_small, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir), dtype = numpy.uint8)
file[start:(start + len(toadd))] = toadd

newpos = start + len(toadd)
fClassName = b'TObjString'
fName = b'Hello World'
fTitle = b'Collectable string class'
file[newpos] = bytes(str(len(fClassName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fClassName))] = numpy.frombuffer(fClassName, dtype = numpy.uint8)
newpos = newpos + len(fClassName)
file[newpos] = bytes(str(len(fName)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fName))] = numpy.frombuffer(fName, dtype = numpy.uint8)
newpos = newpos + len(fName)
file[newpos] = bytes(str(len(fTitle)),"ascii")
newpos = newpos + 1
file[newpos:(newpos + len(fTitle))] = numpy.frombuffer(fTitle, dtype = numpy.uint8)
newpos = newpos + len(fTitle)

# %%
#Examine bytes of target file
f = open("tests/samples/dummy.root", "rb")
count = 0
try:
    byte = f.read(1)
    while byte != "":
        print (count, " ", byte)
        count = count + 1
        byte = f.read(1)
        if count == 928:
            break
finally:
    f.close()

# %%
#Examine bytes of our file
f = open("uprootTObjString.root", "rb")
count = 0
try:
    byte = f.read(1)
    while byte != "":
        print (count, " ", byte)
        count = count + 1
        byte = f.read(1)
        if count == 928:
            break
finally:
    f.close()

# %%
#Examining target_file
target_file[:count]

# %%
#Examining our file
file[:count]

# %%
#Test - Debug target file with uproot
import uproot
uproot.open("tests/samples/dummy.root")

# %%
#Test - Check hexdump of target file
# !hexdump -C ~/Downloads/uproot/tests/samples/dummy.root

# %%
#Test - uproot is reading is reading our file correctly
import uproot
uproot.open("uprootTObjString.root")

# %%
#Comparing Bytes
for i in range(len(target_file)):
    if file[i] != target_file[i]:
        print (i, file[i], "!=", target_file[i])

# %%
#Test - Check size of file
import os
statinfo_target = os.stat('tests/samples/sample-6.14.00-uncompressed.root')
print ("Size of target file is ", statinfo_target.st_size)
statinfo_copy = os.stat('rootpy.root')
print ("Size of written file is ", statinfo_copy.st_size)
