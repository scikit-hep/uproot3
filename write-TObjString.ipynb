# %%
import struct
import numpy
from write.pointer import Pointer
from write.pusher import Pusher

# %%
#Put all bytes from target file into memmap array
target_file = numpy.memmap(filename = "tests/samples/dummy.root", mode = "r", dtype = numpy.uint8, shape = (928,))

# %%
_format1       = ">4si"
_format2_small = ">iiiiiiBiii18s"
_format2_big   = ">iqqiiiBiqi18s"
_format3       = ">hIIii"
_format4_small = ">iii"
_format4_big   = ">qqq"
_format5       = ">i"
_format_small  = ">ihiIhhii"
_format_big    = ">ihiIhhqq"
_startcheck_format = ">IH"

# %%
name = input("Enter name of the ROOT file - ")
if name.endswith(".root") is False:
    name = name + ".root"
file = numpy.memmap(filename = name, dtype = numpy.uint8, mode = "w+", shape = (928,))
#In the case of a 1D array, the shape is the size of the file
#In ROOT files, the fEND corresponds to the size of the file
#fEND for ~/Downloads/uproot/tests/samples/dummy.root is 928

# %%
#Working on just replacing bytes on target_file
file = numpy.memmap(filename = "uprootTObjString.root", dtype = numpy.uint8, mode = "w+", shape = (928,))
file[:] = target_file[:]

# %%
pointer = Pointer(0)
pusher = Pusher(file)

# %%
#Header bytes
magic = b"root"
fVersion = 61400 #Constant
pusher.numbers(pointer, _format1, magic, fVersion)

#constants for file dummy.root
fBEGIN = 100 #Constant
fEND = 928 
fSeekFree = 874
fNbytesFree = fEND - fSeekFree
nfree = 1
fNbytesName = 56
fUnits = 4
fCompress = 0
fSeekInfo = 318
fNbytesInfo = 434
fUUID = b"\x00\x010\xd5\xf5\xea~\x0b\x11\xe8\xa2D~S\x1f\xac\xbe\xef"
pusher.numbers(pointer, _format2_small, fBEGIN, fEND, fSeekFree, fNbytesFree, nfree, fNbytesName, fUnits, fCompress, fSeekInfo, fNbytesInfo, fUUID)

# %%
#Streamer Key
pointer = Pointer(fSeekInfo)
fNbytes = fNbytesInfo
fVersion = 4
fObjlen = 370
fDatime = 1573188772
fKeylen = 64
fCycle = 1
fSeekKey = pointer.index
fSeekPdir = 100
pusher.numbers(pointer, _format_small, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)

fClassName = b'TList'
fName = b'StreamerInfo'
fTitle = b'Doubly linked list'
pusher.stringer(pointer, fClassName)
pusher.stringer(pointer, fName)
pusher.stringer(pointer, fTitle)

# %%
#TList Streamer
cnt = 1073742190
vers = 5
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID =  0
fBits =  33554432
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name = b""
pusher.stringer(pointer, name)
size = 1
packer = ">i"
pusher.numbers(pointer, packer, size)

bcnt =  1073742168
packer = ">I"
pusher.numbers(pointer, packer, bcnt)

tag =  4294967295
packer = ">I"
pusher.numbers(pointer, packer, tag)

cname = b"TStreamerInfo"
pusher.cnamer(pointer, cname)

# %%
#TStreamerInfo Streamer
pointer.skip(1)

cnt =  1073742146
vers =  9
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

cnt =  1073741848
vers =  1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID = 0
fBits =  50397184
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name = b'TObjString'
title = b''
pusher.stringer(pointer, name)
pusher.stringer(pointer, title)

fCheckSum =  2626570240
fClassVersion = 1
packer = ">Ii"
pusher.numbers(pointer, packer, fCheckSum, fClassVersion)

bcnt =  1073742104
packer = ">I"
pusher.numbers(pointer, packer, bcnt)

tag =  4294967295
packer = ">I"
pusher.numbers(pointer, packer, tag)

cname = b"TObjArray"
pusher.cnamer(pointer, cname)

# %%
#TObjArray Streamer
pointer.skip(1)

cnt =  1073742086
vers =  3
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID =  0
fBits =  33554432
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name =  b''
pusher.stringer(pointer, name)
size =  2
low =  0
packer = ">ii"
pusher.numbers(pointer, packer, size, low)

bcnt =  1073741941
packer = ">I"
pusher.numbers(pointer, packer, bcnt)

tag =  4294967295
packer = ">I"
pusher.numbers(pointer, packer, tag)

cname =  b"TStreamerBase"
pusher.cnamer(pointer, cname)

# %%
#TStreamerBase Streamer
pointer.skip(1)

cnt =  1073741919
vers =  3
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

# %%
#TStreamerElement Streamer
cnt =  1073741909
vers =  4
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

cnt =  1073741862
vers =  1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID =  0
fBits =  50331648
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name = b'TObject'
title = b'Basic ROOT object'
pusher.stringer(pointer, name)
pusher.stringer(pointer, title)

fType =  66
fSize =  0
fArrayLength =  0
fArrayDim =  0
packer = ">iiii"
pusher.numbers(pointer, packer, fType, fSize, fArrayLength, fArrayDim)

fMaxIndex =  [0, -1877229523, 0, 0, 0]
packer = ">i"
pusher.array_pusher(pointer, packer, fMaxIndex)

fTypeName =  b'BASE'
pusher.stringer(pointer, fTypeName)

fBaseVersion =  1
packer = ">i"
pusher.numbers(pointer, packer, fBaseVersion)

bcnt =  1073741940
packer = ">I"
pusher.numbers(pointer, packer, bcnt)

tag =  4294967295
packer = ">I"
pusher.numbers(pointer, packer, tag)

cname =  b"TStreamerString"
pusher.cnamer(pointer, cname)

# %%
#TStreamerString Streamer
pointer.skip(1)

cnt =  1073741916
vers =  2
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

# %%
#TStreamerElement Streamer
cnt =  1073741910
vers =  4
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

cnt =  1073741860
vers =  1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID =  0
fBits =  50331648
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name = b'fString'
title = b'wrapped TString'
pusher.stringer(pointer, name)
pusher.stringer(pointer, title)

fType =  65
fSize =  24
fArrayLength =  0
fArrayDim =  0
packer = ">iiii"
pusher.numbers(pointer, packer, fType, fSize, fArrayLength, fArrayDim)

fMaxIndex =  [0, 0, 0, 0, 0]
packer = ">i"
pusher.array_pusher(pointer, packer, fMaxIndex)

fTypeName =  b'TString'
pusher.stringer(pointer, fTypeName)

n =  0
packer = ">B"
pusher.numbers(pointer, packer, n)

pusher.empty_array_pusher(pointer)

# %%
#Tkey instance
pointer = Pointer(fBEGIN)
fNbytes = 116
fVersion = 4
fObjlen = 72
fDatime = 1573188772
fKeylen = 44
fCycle = 1
fSeekKey = 100
fSeekPdir = 0
packer = _format_small
pusher.numbers(pointer, packer, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)

fClassName = b'TFile'
fName = b'dummy.root'
fTitle = b''
pusher.stringer(pointer, fClassName)
pusher.stringer(pointer, fName)
pusher.stringer(pointer, fTitle)

# %%
#Directory Information
pointer = Pointer(156)
fVersion = 5
fDatimeC = 1573188772
fDatimeM = 1573188772
fNbytesKeys = 122
fNbytesName = fNbytesName
packer = _format3
pusher.numbers(pointer, packer, fVersion, fDatimeC, fDatimeM, fNbytesKeys, fNbytesName)
fSeekDir = 100
fSeekParent = 0
fSeekKeys = 752
packer = _format4_small
pusher.numbers(pointer, packer, fSeekDir, fSeekParent, fSeekKeys)

# %%
#Header Key
pointer = Pointer(fSeekKeys)
fNbytes = 122
fVersion = 4
fObjlen = 48
fDatime = 1573188772
fKeylen = 44
fCycle = 1
fSeekKey = 752
fSeekPdir = 100
packer = _format_small
pusher.numbers(pointer, packer, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)

fClassName = b'TFile'
fName = b'dummy.root'
fTitle = b''
pusher.stringer(pointer, fClassName)
pusher.stringer(pointer, fName)
pusher.stringer(pointer, fTitle)

# %%
#Read number of keys
nkeys = 1
pointer = Pointer(796)
packer = _format5
pusher.numbers(pointer, packer, nkeys)

# %%
#Tkey instance 
fNbytes = 102
fVersion = 4
fObjlen = 28
fDatime = 1573188772
fKeylen = 74
fCycle = 1
fSeekKey = 216
fSeekPdir = 100
packer = _format_small
pusher.numbers(pointer, packer, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)

fClassName = b'TObjString'
fName = b'Hello World'
fTitle = b'Collectable string class'
pusher.stringer(pointer, fClassName)
pusher.stringer(pointer, fName)
pusher.stringer(pointer, fTitle)

# %%
#TObjString Streamer - Have to get from branch
pointer = Pointer(290)
cnt = 1073741848
vers = 1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)
fUniqueID = 0
fBits = 33554432
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

string = b"Hello World"
pusher.stringer(pointer, string)

# %%
#Examine bytes of target file
f = open("tests/samples/dummy.root", "rb")
count = 0
try:
    byte = f.read(1)
    while byte != "":
        print (count, " ", byte)
        count = count + 1
        byte = f.read(1)
        if count == 928:
            break
finally:
    f.close()

# %%
#Examine bytes of our file
f = open("uprootTObjString.root", "rb")
count = 0
try:
    byte = f.read(1)
    while byte != "":
        print (count, " ", byte)
        count = count + 1
        byte = f.read(1)
        if count == 928:
            break
finally:
    f.close()

# %%
#Examining target_file
target_file[:count]

# %%
#Examining our file
file[:count]

# %%
#Test - Debug target file with uproot
import uproot
uproot.open("tests/samples/dummy.root")

# %%
#Test - Check hexdump of target file
# !hexdump -C ~/Downloads/uproot/tests/samples/dummy.root

# %%
#Test - uproot is reading is reading our file correctly
import uproot
uproot.open("uprootTObjString.root")

# %%
#Comparing Bytes
for i in range(len(target_file)):
    if file[i] != target_file[i]:
        print (i, file[i], "!=", target_file[i])

# %%
#Test - Check size of file
import os
statinfo_target = os.stat('tests/samples/sample-6.14.00-uncompressed.root')
print ("Size of target file is ", statinfo_target.st_size)
statinfo_copy = os.stat('rootpy.root')
print ("Size of written file is ", statinfo_copy.st_size)
