# %%
import struct
import numpy
from write.pointer import Pointer
from write.pusher import Pusher

# %%
#Put all bytes from target file into memmap array
target_file = numpy.memmap(filename = "tests/samples/dummy.root", mode = "r", dtype = numpy.uint8, shape = (928,))

# %%
_format1       = ">4si"
_format2_small = ">iiiiiiBiii18s"
_format2_big   = ">iqqiiiBiqi18s"
_format3       = ">hIIii"
_format4_small = ">iii"
_format4_big   = ">qqq"
_format5       = ">i"
_format_small  = ">ihiIhhii"
_format_big    = ">ihiIhhqq"
_startcheck_format = ">IH"

# %%
name = "uprootTObjString.root"
bytename = name.encode("utf-8")

# %%
#New file
file = numpy.memmap(filename = name, dtype = numpy.uint8, mode = "w+", shape = (1,))
#In the case of a 1D array, the shape is the size of the file
#In ROOT files, the fEND corresponds to the size of the file
#fEND for ~/Downloads/uproot/tests/samples/dummy.root is 928

# %%
#Working on just replacing bytes on target_file
file = numpy.memmap(filename = name, dtype = numpy.uint8, mode = "w+", shape = (928,))
file[:] = target_file[:]

# %%
pointer = Pointer(0)
pusher = Pusher(file)

# %%
s = "Hello World"
s = s.encode("utf-8")

# %%
#Header bytes
fCompress = 0 #Constant for now
fSeekInfo = 318

from write.header import Header
header = Header(bytename, fCompress, fSeekInfo)
pusher.head_push(pointer, header)

# %%
#Streamer Key
from write.first_key import First_Key
pointer = Pointer(header.fSeekInfo)
fObjlen = 370
key = First_Key(pointer, fObjlen)
pusher.keyer(pointer, key)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
header.fNbytesInfo = key.fNbytes
pusher.head_push(Pointer(0), header)

# %%
from write.tobjstring import TObjString
tobjstring = TObjString(pusher, pointer)
tobjstring.write()

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#TStreamerInfo Streamer
pointer.skip(1)

cnt =  1073742146
vers =  9
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

cnt =  1073741848
vers =  1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID = 0
fBits =  50397184
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name = b'TObjString'
title = b''
pusher.stringer(pointer, name)
pusher.stringer(pointer, title)

fCheckSum =  2626570240
fClassVersion = 1
packer = ">Ii"
pusher.numbers(pointer, packer, fCheckSum, fClassVersion)

bcnt =  1073742104
packer = ">I"
pusher.numbers(pointer, packer, bcnt)

tag =  4294967295
packer = ">I"
pusher.numbers(pointer, packer, tag)

cname = b"TObjArray"
pusher.cnamer(pointer, cname)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#TObjArray Streamer
pointer.skip(1)

cnt =  1073742086
vers =  3
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID =  0
fBits =  33554432
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name =  b''
pusher.stringer(pointer, name)
size =  2
low =  0
packer = ">ii"
pusher.numbers(pointer, packer, size, low)

bcnt =  1073741941
packer = ">I"
pusher.numbers(pointer, packer, bcnt)

tag =  4294967295
packer = ">I"
pusher.numbers(pointer, packer, tag)

cname =  b"TStreamerBase"
pusher.cnamer(pointer, cname)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#TStreamerBase Streamer
pointer.skip(1)

cnt =  1073741919
vers =  3
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#TStreamerElement Streamer
cnt =  1073741909
vers =  4
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

cnt =  1073741862
vers =  1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID =  0
fBits =  50331648
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name = b'TObject'
title = b'Basic ROOT object'
pusher.stringer(pointer, name)
pusher.stringer(pointer, title)

fType =  66
fSize =  0
fArrayLength =  0
fArrayDim =  0
packer = ">iiii"
pusher.numbers(pointer, packer, fType, fSize, fArrayLength, fArrayDim)

fMaxIndex =  [0, -1877229523, 0, 0, 0]
packer = ">i"
pusher.array_pusher(pointer, packer, fMaxIndex)

fTypeName =  b'BASE'
pusher.stringer(pointer, fTypeName)

fBaseVersion =  1
packer = ">i"
pusher.numbers(pointer, packer, fBaseVersion)

bcnt =  1073741940
packer = ">I"
pusher.numbers(pointer, packer, bcnt)

tag =  4294967295
packer = ">I"
pusher.numbers(pointer, packer, tag)

cname =  b"TStreamerString"
pusher.cnamer(pointer, cname)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#TStreamerString Streamer
pointer.skip(1)

cnt =  1073741916
vers =  2
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#TStreamerElement Streamer
cnt =  1073741910
vers =  4
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

cnt =  1073741860
vers =  1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)

fUniqueID =  0
fBits =  50331648
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

name = b'fString'
title = b'wrapped TString'
pusher.stringer(pointer, name)
pusher.stringer(pointer, title)

fType =  65
fSize =  24
fArrayLength =  0
fArrayDim =  0
packer = ">iiii"
pusher.numbers(pointer, packer, fType, fSize, fArrayLength, fArrayDim)

fMaxIndex =  [0, 0, 0, 0, 0]
packer = ">i"
pusher.array_pusher(pointer, packer, fMaxIndex)

fTypeName =  b'TString'
pusher.stringer(pointer, fTypeName)

n =  0
packer = ">B"
pusher.numbers(pointer, packer, n)

pusher.empty_array_pusher(pointer)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Tkey instance
from write.begin_key import Begin_Key
pointer = Pointer(header.fBEGIN)
fName = bytename
key = Begin_Key(fName)
pusher.keyer(pointer, key)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Junk 
pusher.stringer(pointer, fName)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Directory Information
from write.directoryinfo import DirectoryInfo
fNbytesKeys = 122
fNbytesName = header.fNbytesName
fSeekKeys = 752
directory = DirectoryInfo(fNbytesKeys, fNbytesName, fSeekKeys)
pusher.director(pointer, directory)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Header Key
pointer = Pointer(fSeekKeys)
fNbytes = 122
fVersion = 4
fObjlen = 48
fDatime = 1573188772
fKeylen = 44
fCycle = 1
fSeekKey = 752
fSeekPdir = 100
packer = _format_small
pusher.numbers(pointer, packer, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)

fClassName = b'TFile'
fName = bytename
fTitle = b''
pusher.stringer(pointer, fClassName)
pusher.stringer(pointer, fName)
pusher.stringer(pointer, fTitle)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Read number of keys
nkeys = 1
packer = _format5
pusher.numbers(pointer, packer, nkeys)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Tkey instance 
fVersion = 4
fObjlen = 17 + len(s) #Length of TObjString Branch Streamer
fDatime = 1573188772
fKeylen = 74
fNbytes = fObjlen + fKeylen
fCycle = 1
fSeekKey = 216
fSeekPdir = 100
packer = _format_small
pusher.numbers(pointer, packer, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)

fClassName = b'TObjString'
fName = s
fTitle = b'Collectable string class'
pusher.stringer(pointer, fClassName)
pusher.stringer(pointer, fName)
pusher.stringer(pointer, fTitle)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Junk
pointer = Pointer(fSeekKey)
fVersion = 4
fObjlen = 17 + len(s) #Length of TObjString Branch Streamer
fDatime = 1573188772
fKeylen = 74
fNbytes = fObjlen + fKeylen
fCycle = 1
fSeekKey = 216
fSeekPdir = 100
packer = _format_small
pusher.numbers(pointer, packer, fNbytes, fVersion, fObjlen, fDatime, fKeylen, fCycle, fSeekKey, fSeekPdir)

fClassName = b'TObjString'
fName = s
fTitle = b'Collectable string class'
pusher.stringer(pointer, fClassName)
pusher.stringer(pointer, fName)
pusher.stringer(pointer, fTitle)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#TObjString Streamer - Have to get from branch
cnt = fObjlen - 4
kByteCountMask = numpy.int64(0x40000000)
cnt = cnt | kByteCountMask
vers = 1
packer = ">IH"
pusher.numbers(pointer, packer, cnt, vers)

version = 1
packer = ">h"
pusher.numbers(pointer, packer, version)
fUniqueID = 0
fBits = 33554432
packer = ">II"
pusher.numbers(pointer, packer, fUniqueID, fBits)

string = s
pusher.stringer(pointer, string)

if pointer.index>header.fEND:
    header.fEND = pointer.index
    header.fSeekFree = pointer.index
    
pusher.head_push(Pointer(0), header)

# %%
#Examine bytes of target file
f = open("tests/samples/dummy.root", "rb")
count = 0
try:
    byte = f.read(1)
    while byte != "":
        print (count, " ", byte)
        count = count + 1
        byte = f.read(1)
        if count == 928:
            break
finally:
    f.close()

# %%
#Examine bytes of our file
f = open(name, "rb")
count = 0
try:
    byte = f.read(1)
    while byte != "":
        print (count, " ", byte)
        count = count + 1
        byte = f.read(1)
        if count == header.fEND:
            break
finally:
    f.close()

# %%
#Examining target_file
target_file[:count]

# %%
#Examining our file
file[:count]

# %%
#Test - Debug target file with uproot
import uproot
uproot.open("tests/samples/dummy.root")

# %%
#Test - Check hexdump of target file
# !hexdump -C ~/Downloads/uproot/tests/samples/dummy.root

# %%
#Test - uproot is reading is reading our file correctly
import uproot
uproot.open("uprootTObjString.root")

# %%
#Test - Check size of file
import os
statinfo_target = os.stat("tests/samples/dummy.root")
print ("Size of target file is ", statinfo_target.st_size)
statinfo_copy = os.stat('uprootTObjString.root')
print ("Size of written file is ", statinfo_copy.st_size)
